# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\atanu\OneDrive\Desktop\data science assignment\EDA1\Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.shape
# Out:
# (2126, 14)

# %%
df['NSP']=df['NSP'].astype('category')

# %%
df['Tendency']=df['Tendency'].astype('category')

# %%
df.dtypes
# Out:
# LB           float64
# AC           float64
# FM           float64
# UC           float64
# DL           float64
# DS           float64
# DP           float64
# ASTV         float64
# MSTV         float64
# ALTV         float64
# MLTV         float64
# Width        float64
# Tendency    category
# NSP         category
# dtype: object

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df['LB']=df['LB'].fillna(df['LB'].mean())
df['AC']=df['AC'].fillna(df['AC'].mean())
df['DS']=df['DS'].fillna(df['DS'].mean())
df['DP']=df['DP'].fillna(df['DP'].mean())
df['MLTV']=df['MLTV'].fillna(df['MLTV'].mean())
df['Width']=df['Width'].fillna(df['Width'].mean())

# %%
df['Tendency']=df['Tendency'].fillna(df['Tendency'].mode().iloc[0])
df['NSP']=df['NSP'].fillna(df['NSP'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df1=df.iloc[:,0:12]

# %%
df1.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['LB'],bins=5,edgecolor='black')
plt.xlabel('Average fetal heart rate')
plt.ylabel('density of heart rate')
plt.title('Fetal Heart rate')
# Out:
# Text(0.5, 1.0, 'Fetal Heart rate')

# %%
import matplotlib.pyplot as plt
plt.hist(df['AC'],bins=5,edgecolor='black')
plt.xlabel('Accelerations of fetal heart rate')
plt.ylabel('density ')
plt.title('Fetal well being')
# Out:
# Text(0.5, 1.0, 'Fetal well being')

# %%
import matplotlib.pyplot as plt
plt.hist(df['FM'],bins=5,edgecolor='black')
plt.xlabel('Fetal movement')
plt.ylabel('density ')
plt.title('Fetal Movement')
# Out:
# Text(0.5, 1.0, 'Fetal Movement')

# %%
import matplotlib.pyplot as plt
plt.hist(df['UC'],bins=5,edgecolor='black')
plt.xlabel('Utrine contraction')
plt.ylabel('density ')
plt.title('Utrine contraction')
# Out:
# Text(0.5, 1.0, 'Utrine contraction')

# %%
import matplotlib.pyplot as plt
plt.hist(df['DL'],bins=5,edgecolor='black')
plt.xlabel(' fetal distress')
plt.ylabel('density ')
plt.title('Fetal distress')
# Out:
# Text(0.5, 1.0, 'Fetal distress')

# %%
import matplotlib.pyplot as plt
plt.hist(df['DS'],bins=5,edgecolor='black')
plt.xlabel('Short Deceleration')
plt.ylabel('density ')
plt.title('Short deceleration of Fetal')
# Out:
# Text(0.5, 1.0, 'Short deceleration of Fetal')

# %%
import matplotlib.pyplot as plt
plt.hist(df['DP'],bins=5,edgecolor='black')
plt.xlabel('Deceleration of fetal heart rate')
plt.ylabel('density ')
plt.title('Fetal decelaration')
# Out:
# Text(0.5, 1.0, 'Fetal decelaration')

# %%
import matplotlib.pyplot as plt
plt.hist(df['ASTV'],bins=5,edgecolor='black')
plt.xlabel('Abnormal Short Term Variability')
plt.ylabel('density ')
plt.title('Fetal ASTV')
# Out:
# Text(0.5, 1.0, 'Fetal ASTV')

# %%
import matplotlib.pyplot as plt
plt.hist(df['ALTV'],bins=5,edgecolor='black')
plt.xlabel('Abnormal long term variability')
plt.ylabel('density ')
plt.title('Abnormal long term variability in FHR')
# Out:
# Text(0.5, 1.0, 'Abnormal long term variability in FHR')

# %%
df['Tendency'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['NSP'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# C:\Users\atanu\.ipython\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df1=df.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.062839  0.018776 -0.166201 -0.126536 -0.005438
# AC       -0.062839  1.000000  0.009432  0.071863 -0.093196 -0.033101
# FM        0.018776  0.009432  1.000000 -0.053226  0.009718  0.029899
# UC       -0.166201  0.071863 -0.053226  1.000000  0.190128 -0.006922
# DL       -0.126536 -0.093196  0.009718  0.190128  1.000000  0.058430
# DS       -0.005438 -0.033101  0.029899 -0.006922  0.058430  1.000000
# DP       -0.047724 -0.083277  0.121274  0.070501  0.144940  0.004285
# ASTV      0.241857 -0.230439 -0.032691 -0.181161 -0.069361  0.008425
# MSTV     -0.169561  0.133649  0.017055  0.189406  0.410102  0.016077
# ALTV      0.210446 -0.271041 -0.011936 -0.227304 -0.186967 -0.004392
# MLTV     -0.003457 -0.104875 -0.006237 -0.049351 -0.165198  0.034349
# Width    -0.118425  0.234735  0.097204  0.107159  0.408664  0.040832
# Tendency  0.236583  0.030067 -0.017819 -0.066832 -0.023914 -0.015380
# ...

# %%
# week correlation between variables nearly 0.2 to 0.3

# %%
import seaborn as sns
sns.heatmap(df)
# Out:
# <Axes: >

# %%
#nearly <100 woman hqve fetal heart rate 60-80,lower fetal well bing and lower fetal movement and also have low non structural protin
# may be they are in the first stage of pregnency
# more than 1750 patient have fetal heart rate between 120-140 but acecrelation of fetal (well-being of fetal) is <1400
# nearly 1700 woman have third trimester of pregnency as they have high fetal rate,normal acceleration,normal fetal movement
# 75% have 1 non structural protine mean but nearly 15% have protine contained less than 1
