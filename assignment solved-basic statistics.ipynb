# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\atanu\OneDrive\Desktop\sales_data_with_discounts.csv")

# %%
data
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
data.iloc[:,8:13].mean()
# Out:
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
data.iloc[:,8:13].std()
# Out:
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
data.iloc[:,8:12].mode()
# Out:
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount
# 0        400.0            24300.0           5.007822        69.177942
# 1        450.0                NaN           5.055218        73.025199
# 2        500.0                NaN           5.059801        93.649161
# 3       1300.0                NaN           5.072124        94.682735
# 4       8100.0                NaN           5.084108       102.705757
# ..         ...                ...                ...              ...
# 445        NaN                NaN          19.940610     17900.983733
# 446        NaN                NaN          19.965340     21153.498820
# 447        NaN                NaN          19.976879     21496.675367
# 448        NaN                NaN          19.982257     25328.224204
# 449        NaN                NaN          19.992407     25738.022194
#
# [450 rows x 4 columns]

# %% [markdown]
# # Average price has outlyer-but low deviation exists
# # low deviation in sales value- some products are higly profitablr though price    are less but sales value high
#  # high variation is discount rate-discount rate has outlyer
#  # Net sales values have wide deviation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(data['Discount Rate (%)'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('Discount rate')
plt.ylabel('density')
plt.title('discount rate %')
# Out:
# Text(0.5, 1.0, 'discount rate %')

# %%
plt.hist(data['Avg Price'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('average price')
plt.ylabel('density')
plt.title('Average price')
# Out:
# Text(0.5, 1.0, 'Average price')

# %%
plt.hist(data['Total Sales Value'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('Total Sales Value')
plt.ylabel('density')
plt.title('Total Sales Value')
# Out:
# Text(0.5, 1.0, 'Total Sales Value')

# %%
plt.hist(data['Discount Amount'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('discount amount')
plt.ylabel('density')
plt.title('Discount Amount')
# Out:
# Text(0.5, 1.0, 'Discount Amount')

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
plt.hist(data['Net Sales Value'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('Net Sales Value ')
plt.ylabel('density ')
plt.title('Net Sales Value ')
# Out:
# Text(0.5, 1.0, 'Net Sales Value ')

# %%
fig=plt.figure(figsize=(13,5))
plt.subplot(1,4,1)
plt.hist(data['Avg Price'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('average price')
plt.ylabel('density')
plt.title('Average price')

plt.subplot(1,4,2)
plt.hist(data['Total Sales Value'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('Total Sales Value')
plt.ylabel('density')
plt.title('Total Sales Value')

plt.subplot(1,4,3)
plt.hist(data['Discount Rate (%)'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('Discount rate')
plt.ylabel('density')
plt.title('discount rate %')

plt.subplot(1,4,4)
plt.hist(data['Discount Amount'],facecolor='blue',edgecolor="black",bins=5)
plt.xlabel('discount amount')
plt.ylabel('density')
plt.title('Discount Amount')
# Out:
# Text(0.5, 1.0, 'Discount Amount')

# %%
from scipy.stats import skew
print("skew of average price",data['Avg Price'].skew())
# Out:
# skew of average price 1.9088730767759727

# %%
from scipy.stats import kurtosis
print("kurtosis of average price",data['Avg Price'].kurtosis())
# Out:
# kurtosis of average price 2.07565498004372

# %%
from scipy.stats import skew
print("skew of total sales value",data['Total Sales Value'].skew())
# Out:
# skew of total sales value 1.5347293238977937

# %%
from scipy.stats import kurtosis
print("kurtosis of total sales value",data['Total Sales Value'].kurtosis())
# Out:
# kurtosis of total sales value 1.0249161068455352

# %%
from scipy.stats import skew
print("skew of discount rate",data['Discount Rate (%)'].skew())
# Out:
# skew of discount rate -1.0622943696988825

# %%
from scipy.stats import kurtosis
print("kurtosis of discount rate",data['Discount Rate (%)'].kurtosis())
# Out:
# kurtosis of discount rate -0.1785407468981699

# %%
from scipy.stats import skew
print("skew of discoubt amount",data['Discount Amount'].skew())
# Out:
# skew of discoubt amount 1.9130377339538271

# %%
from scipy.stats import kurtosis
print("krtosis of discoubt amount",data['Discount Amount'].kurtosis())
# Out:
# krtosis of discoubt amount 3.8311859719016343

# %%
from scipy.stats import skew
print('skew of net sales value',data['Net Sales Value'].skew())
# Out:
# skew of net sales value 1.5408217575344376

# %%
from scipy.stats import kurtosis
print('kurtosis of net sales value',data['Net Sales Value'].kurtosis())
# Out:
# kurtosis of net sales value 1.0124678624199062

# %% [markdown]
# Avrage price,Total sales,discount amount,net sales values all are positively skewed and kutosis is also positive
# discount rate is negativly skewed and kurtosis is also negative
# kustosis of discount amount is highest one

# %%
# avg_price,total sales value,discount amonut have psitive skew have more outlayers
# discount rate have negative skew
# all are asymetrical curv

# %%
sns.boxplot(data['Avg Price'])
plt.xlabel('Avg price')
plt.ylabel('density')
plt.title('average price')
# Out:
# Text(0.5, 1.0, 'average price')

# %%
# average price of the products are nearly 10000 but some product"s price are  nearly 50000 and 60000 which is an outlyer of this plot

# %%
sns.boxplot(data['Total Sales Value'])
plt.xlabel('Total Sales Value')
plt.ylabel('density')
plt.title('TOTAL SALES VALUE')
# Out:
# Text(0.5, 1.0, 'TOTAL SALES VALUE')

# %%
# sales values are mostly more than interquartile range and 
#  sales prices are mostly from 20000 to 50000

# %%
sns.boxplot(data['Discount Rate (%)'])
plt.xlabel('Discount rate')
plt.ylabel('density')
plt.title('Discount Rate (%)')
# Out:
# Text(0.5, 1.0, 'Discount Rate (%)')

# %%
sns.boxplot(data['Discount Amount'])
plt.xlabel('Discount amount')
plt.ylabel('density')
plt.title('Discount Amount')
# Out:
# Text(0.5, 1.0, 'Discount Amount')

# %%
sns.boxplot(data['Net Sales Value'])
plt.xlabel('Net Sales Value')
plt.ylabel('density')
plt.title('Net Sales Value')
# Out:
# Text(0.5, 1.0, 'Net Sales Value')

# %%
plt.bar(data['BU'],data['Volume'])
# Out:
# <BarContainer object of 450 artists>

# %%
data['Brand'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Brand'>

# %%
fig=plt.figure(figsize=(13,9))
plt.bar(data['Model'],data['Volume'])
# Out:
# <BarContainer object of 450 artists>

# %%
import scipy
from scipy import stats

# %%
z_score=stats.zscore(data[['Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']])

# %%
z_score
# Out:
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0     0.091173           2.925721          -0.830289         3.952816
# 1    -0.019570           1.330995          -0.852661         1.849014
# 2     0.312659           1.562775          -1.351631         1.622995
# 3     0.534146           1.719276          -1.949723         1.113807
# 4    -0.130313          -0.188452           0.673739         0.227852
# ..         ...                ...                ...              ...
# 445  -0.506840          -0.618334           0.076009        -0.653541
# 446  -0.434857          -0.360801           0.451097        -0.152191
# 447  -0.490229          -0.606448           0.903793        -0.608140
# 448  -0.473617          -0.556923           0.388474        -0.530379
# 449  -0.407171          -0.608429           0.042235        -0.637345
#
#      Net Sales Value
# 0           2.804756
# 1           1.271026
# 2           1.545675
# 3           1.765810
# ...

# %%
data.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
import pandas as pd
df=pd.get_dummies(data)
df
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...
